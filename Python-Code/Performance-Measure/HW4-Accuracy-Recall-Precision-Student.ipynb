# %% [markdown]
# # Homework Assignment 4
# ## Accuracy, Recall, and Precision
#
# **Type:** Multiple choice
# **Questions:** 6
# **Code required:** No
# **Total points:** 60
#
# Use the following information from the lecture note:
#
# - **0 = not cancer**
# - **1 = cancer**
#
# Confusion matrix format:
#
# |  | Predicted 0 | Predicted 1 |
# |---|---|---|
# | **Actual 0** | TN | FP |
# | **Actual 1** | FN | TP |
#
# For the tumor example in the lecture note:
#
# - **TP = 4**
# - **TN = 5**
# - **FP = 2**
# - **FN = 1**
#
# So:
#
# - **Accuracy = 0.75**
# - **Recall = 0.80**
# - **Precision ≈ 0.667**
#
# Write the letter of your answer in the space provided after each question.

# %% [markdown]
# ---
# ### Question 1 — 10 pts
#
# Using **TP = 4, TN = 5, FP = 2, and FN = 1**, what is the model's **accuracy**?
#
# $$\text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}$$
#
# **A)** 4/12 ≈ 0.333
#
# **B)** 6/12 = 0.500
#
# **C)** 9/12 = 0.750
#
# **D)** 11/12 ≈ 0.917
#
# **Your answer (A/B/C/D):** ______

# %% [markdown]
# ---
# ### Question 2 — 10 pts
#
# Suppose a model always predicts **cancer (1)** for every patient. The test set has **5 cancer cases** and **7 non-cancer cases**.
#
# What would its **recall** and **precision** be?
#
# **A)** Recall = 1.0, Precision ≈ 0.417
#
# **B)** Recall = 0.0, Precision = 1.0
#
# **C)** Recall = 0.5, Precision = 0.5
#
# **D)** Recall = 1.0, Precision = 1.0
#
# **Your answer (A/B/C/D):** ______

# %% [markdown]
# ---
# ### Question 3 — 10 pts
#
# In the lecture note, the model has:
#
# - **Recall = 0.80**
# - **Precision ≈ 0.667**
#
# Which statement best describes what this means?
#
# **A)** The model is correct 80% of the time overall, and 66.7% of all predictions match the true label
#
# **B)** The model catches 80% of real cancers, and when it predicts cancer it is correct about two-thirds of the time
#
# **C)** The model has 80% accuracy on the training set and 66.7% accuracy on the test set
#
# **D)** Recall and precision should always be equal, so these values mean the model is wrong
#
# **Your answer (A/B/C/D):** ______

# %% [markdown]
# ---
# ### Question 4 — 10 pts
#
# Suppose a doctor lowers the decision threshold from **0.5** to **0.3** so the model is more likely to predict **cancer**.
#
# What is the most likely effect?
#
# **A)** Recall decreases and precision increases
#
# **B)** Recall increases and precision decreases
#
# **C)** Both recall and precision increase
#
# **D)** Both recall and precision decrease
#
# **Your answer (A/B/C/D):** ______

# %% [markdown]
# ---
# ### Question 5 — 10 pts
#
# The lecture note states that for cancer screening, **recall** is usually more important than precision.
#
# Which statement best explains why?
#
# **A)** Recall is always mathematically larger than precision, so it is more reliable
#
# **B)** A false positive means a real cancer is missed, which is more dangerous than further testing
#
# **C)** A false negative means a real cancer is missed and may go untreated, which is more dangerous than a false alarm
#
# **D)** Precision cannot be calculated when false negatives exist, so recall is the only valid metric
#
# **Your answer (A/B/C/D):** ______

# %% [markdown]
# ---
# ### Question 6 — 10 pts
#
# Suppose a model always predicts **not cancer (0)** for every patient. The test set has **5 cancer cases** and **7 non-cancer cases**.
#
# What would its **accuracy** be, and why is that misleading?
#
# **A)** 5/12 ≈ 0.417, because only the malignant cases count toward accuracy
#
# **B)** 7/12 ≈ 0.583, because it correctly labels all non-cancer cases but misses every real cancer
#
# **C)** 1.0, because it avoids all false positives
#
# **D)** 0.0, because the model never predicts cancer
#
# **Your answer (A/B/C/D):** ______
