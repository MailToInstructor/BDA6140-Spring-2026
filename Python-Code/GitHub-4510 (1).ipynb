# %%
# !git clone https://github.com/MailToInstructor/BDA6140-Spring-2026.git
# Out:
# Cloning into 'BDA6140-Spring-2026'...
# ...

# %%
# mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm -rf /content/BDA6140-Spring-2026/*

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Teaching/BDA6140/GitHub/BDA6140-Spring-2026/"* /content/BDA6140-Spring-2026/

# %%
# %cd /content/BDA6140-Spring-2026/
# Out:
# /content/BDA6140-Spring-2026

# %%
# !ls
# Out:
# Data  Python-Code

# %%
rm *.ipynb
# Out:
# rm: cannot remove '*.ipynb': No such file or directory

# %%
# !ls
# Out:
# Data  Python-Code

# %%
# !git config --global user.name "Joon Son"
# !git config --global user.email "MailToInstructor@gmail.com"

# %% [markdown]
# #Time to add

# %%
# !git add -A

# %% [markdown]
# #Time to Commit

# %%
# !git commit -m "new upload"
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean

# %% [markdown]
# #Time to Push

# %%
# !git push https://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@github.com/MailToInstructor/BDA6140-Spring-2026.git
# Out:
# Enumerating objects: 21, done.
# Counting objects: 100% (21/21), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (20/20), done.
# Writing objects: 100% (21/21), 5.92 MiB | 8.72 MiB/s, done.
# Total 21 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), done.
# To https://github.com/MailToInstructor/BDA6140-Spring-2026.git
#  * [new branch]      main -> main
