# %%
# !git clone https://github.com/MailToInstructor/BDA6140-Spring-2026.git
# Out:
# Cloning into 'BDA6140-Spring-2026'...
# ...

# %%
# mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/BDA6140-Spring-2026/*

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Teaching/BDA6140/GitHub/BDA6140-Spring-2026/"* /content/IST4510-Spring-2026/

# %%
# %cd /content/BDA6140-Spring-2026/
# Out:
# /content/BDA6140-Spring-2026

# %%
# !ls

# %%
rm *.ipynb
# Out:
# rm: cannot remove '*.ipynb': No such file or directory

# %%
# !ls
# Out:
# Data  Python-Code

# %%
# !git config --global user.name "Joon Son"
# !git config --global user.email "clearmindlearn@gmail.com"

# %% [markdown]
# #Time to add

# %%
# !git add -A

# %% [markdown]
# #Time to Commit

# %%
# !git commit -m "new upload"
# Out:
# [main e25c2b0] new upload
#  2 files changed, 2 insertions(+), 348 deletions(-)
#  rewrite Python-Code/Multiple-Linear-Regression/HW-Multi-Reg-Part1.ipynb (100%)
#  rewrite Python-Code/Multiple-Linear-Regression/multiple_regression.ipynb (93%)

# %% [markdown]
# #Time to Push

# %%
# !git push https://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@github.com/clearmindlearn/IST4510-Spring-2026.git
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 5.28 KiB | 675.00 KiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/clearmindlearn/IST4510-Spring-2026.git
#    1739572..e25c2b0  main -> main
