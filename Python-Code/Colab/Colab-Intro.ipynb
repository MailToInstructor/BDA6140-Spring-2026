# %%
#Mount google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd   #pd is an alias for pandas

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Teaching/BDA6140/GitHub/BDA6140-Spring-2026/Data/CompactSUV.csv")
df
# Out:
#           Make           Model  Overall Score Recommended Owner Satisfaction  \
# 0       Subaru        Forester             84         Yes                  +
# 1        Honda             CRV             83         Yes                 ++
# 2       Toyota            Rav4             81         Yes                 ++
# 3       Nissan           Rogue             73         Yes                  +
# 4        Mazda            CX-5             71         Yes                 ++
# 5          Kia        Sportage             71         Yes                  +
# 6         Ford          Escape             69         Yes                  0
# 7   Volkswagen  Tiguan Limited             67          No                  0
# 8   Volkswagen          Tiguan             65          No                  +
# 9   Mitsubishi       Outlander             63          No                  0
# 10   Chevrolet         Equinox             63          No                  0
# ...

# %%
df2 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Teaching/BDA6140/GitHub/BDA6140-Spring-2026/Data/dataset.xlsx", sheet_name = "CarBuyers")

df2
# Out:
#    CustomerID               Name         City  Age Sex
# 0         981         Jane Smith       Boston   56   F
# 1         459          Tom Perez    Worcester   49   M
# 2         272     Kate Greenbaum    Worcester   65   F
# 3         832  Alisha Washington  Springfield   42   F
# 4         553         Ken Castro       Boston   55   M
# 5         776        Leonard Liu  Springfield   57   M
# 6         379       Sam Thurston    Worcester   40   M
# 7         742      Sydney Benoit       Boston   67   F
